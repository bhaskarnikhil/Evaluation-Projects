# %% [markdown]
# # IMPORTING PYTHON PACKAGES

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import zscore
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.linear_model import ElasticNet
from sklearn.externals import joblib
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Anaconda\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %% [markdown]
# # IMPORTING DATASET

# %%
df_baseball=pd.read_csv('baseball.csv')
df_baseball
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0   724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1   696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3   622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4   689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 5   891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7   10
# 6   764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7   713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8   644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9   748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9
# 11  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5   13
# 12  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2   12
# 13  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6   12
# 14  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5   15
# 15  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1   15
# 16  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0   13
# 17  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6   21
# 18  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1    7
# 19  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2    8
# 20  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1   14
# 21  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4   13
# 22  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0   12
# 23  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3   10
# 24  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1    7
# 25  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6   21
# 26  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7   18
# 27  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1   12
# 28  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1    6
# 29  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4    4
#
#     SV    E    W
# 0   56   88   95
# 1   45   86   83
# 2   38   79   81
# 3   37  101   76
# 4   35   86   74
# 5   34   88   93
# 6   48   93   87
# 7   43   77   81
# 8   60   95   80
# 9   40   97   78
# 10  45  119   88
# 11  39   85   86
# 12  46   93   85
# 13  45   94   76
# 14  28  126   68
# 15  62   96  100
# 16  54  122   98
# 17  48  111   97
# 18  40  116   68
# 19  35   90   64
# 20  50   88   90
# 21  41   90   83
# 22  35   77   71
# 23  44   90   67
# 24  35  117   63
# 25  47   75   92
# 26  41   78   84
# 27  44   86   79
# 28  41   92   74
# 29  36   95   68

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
df_baseball.head()
# Out:
#      R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  SV  \
# 0  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8  56
# 1  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12  45
# 2  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10  38
# 3  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9  37
# 4  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12  35
#
#      E   W
# 0   88  95
# 1   86  83
# 2   79  81
# 3  101  76
# 4   86  74

# %%
df_baseball.tail()
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 25  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6   21
# 26  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7   18
# 27  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1   12
# 28  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1    6
# 29  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4    4
#
#     SV   E   W
# 25  47  75  92
# 26  41  78  84
# 27  44  86  79
# 28  41  92  74
# 29  36  95  68

# %%
df_baseball.shape
# Out:
# (30, 17)

# %%
df_baseball.dtypes
# Out:
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# W        int64
# dtype: object

# %%
df_baseball.columns
# Out:
# Index(['R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER', 'ERA',
#        'CG', 'SHO', 'SV', 'E', 'W'],
#       dtype='object')

# %%
df_baseball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
# R      30 non-null int64
# AB     30 non-null int64
# H      30 non-null int64
# 2B     30 non-null int64
# 3B     30 non-null int64
# HR     30 non-null int64
# BB     30 non-null int64
# SO     30 non-null int64
# SB     30 non-null int64
# RA     30 non-null int64
# ER     30 non-null int64
# ERA    30 non-null float64
# CG     30 non-null int64
# SHO    30 non-null int64
# SV     30 non-null int64
# E      30 non-null int64
# W      30 non-null int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df_baseball.describe()
# Out:
#                 R           AB            H          2B         3B  \
# count   30.000000    30.000000    30.000000   30.000000  30.000000
# mean   688.233333  5516.266667  1403.533333  274.733333  31.300000
# std     58.761754    70.467372    57.140923   18.095405  10.452355
# min    573.000000  5385.000000  1324.000000  236.000000  13.000000
# 25%    651.250000  5464.000000  1363.000000  262.250000  23.000000
# 50%    689.000000  5510.000000  1382.500000  275.500000  31.000000
# 75%    718.250000  5570.000000  1451.500000  288.750000  39.000000
# max    891.000000  5649.000000  1515.000000  308.000000  49.000000
#
#                HR          BB          SO          SB          RA          ER  \
# count   30.000000   30.000000    30.00000   30.000000   30.000000   30.000000
# mean   163.633333  469.100000  1248.20000   83.500000  688.233333  635.833333
# std     31.823309   57.053725   103.75947   22.815225   72.108005   70.140786
# min    100.000000  375.000000   973.00000   44.000000  525.000000  478.000000
# 25%    140.250000  428.250000  1157.50000   69.000000  636.250000  587.250000
# 50%    158.500000  473.000000  1261.50000   83.500000  695.500000  644.500000
# 75%    177.000000  501.250000  1311.50000   96.500000  732.500000  679.250000
# max    232.000000  570.000000  1518.00000  134.000000  844.000000  799.000000
#
#              ERA         CG        SHO         SV           E           W
# count  30.000000  30.000000  30.000000  30.000000   30.000000   30.000000
# mean    3.956333   3.466667  11.300000  43.066667   94.333333   80.966667
# std     0.454089   2.763473   4.120177   7.869335   13.958889   10.453455
# min     2.940000   0.000000   4.000000  28.000000   75.000000   63.000000
# 25%     3.682500   1.000000   9.000000  37.250000   86.000000   74.000000
# 50%     4.025000   3.000000  12.000000  42.000000   91.000000   81.000000
# 75%     4.220000   5.750000  13.000000  46.750000   96.750000   87.750000
# max     5.040000  11.000000  21.000000  62.000000  126.000000  100.000000

# %% [markdown]
# Data in all the columns appear to have normal distribution (mean very close to 50th percentile).

# %%
sns.heatmap(df_baseball.isnull(),annot=True)

# %%
df_baseball.isnull().sum()
# Out:
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# W      0
# dtype: int64

# %% [markdown]
# CHECKING DATA SKEWNESS

# %%
df_baseball.skew()
# Out:
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# W      0.047089
# dtype: float64

# %% [markdown]
# REMOVING DATA SKEWNESS

# %%
for col in df_baseball.columns:
    if df_baseball.skew().loc[col]>0.55:
        df_baseball[col]=np.log1p(df_baseball[col])
df_baseball.skew()
# Out:
# R      0.744813
# AB     0.183437
# H      0.628584
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG    -0.325962
# SHO   -0.589640
# SV     0.163057
# E      0.632916
# W      0.047089
# dtype: float64

# %% [markdown]
# CHECKING OUTLIERS

# %%
z=np.abs(zscore(df_baseball))
print(z.shape)
print(np.where(z>3))
# Out:
# (30, 17)
# (array([5], dtype=int64), array([0], dtype=int64))

# %%
print(df_baseball.iloc[5,])
# Out:
# R         6.793466
# AB     5509.000000
# H         7.300473
# 2B      308.000000
# 3B       17.000000
# HR      232.000000
# BB      570.000000
# SO     1151.000000
# SB       88.000000
# RA      670.000000
# ER      609.000000
# ERA       3.800000
# CG        2.079442
# SHO       2.397895
# SV        3.555348
# E         4.488636
# W        93.000000
# Name: 5, dtype: float64

# %% [markdown]
# This outlier may be ingored.

# %%
df_final=df_baseball

# %% [markdown]
# BOXPLOT

# %%
df_final.plot.box()

# %% [markdown]
# CORRELATION

# %%
df_final.corr()
# Out:
#             R        AB         H        2B        3B        HR        BB  \
# R    1.000000  0.338137  0.481814  0.566754 -0.045152  0.676421  0.395835
# AB   0.338137  1.000000  0.740101  0.453370  0.435422 -0.066983 -0.136414
# H    0.481814  0.740101  1.000000  0.566231  0.476582 -0.091319 -0.117854
# 2B   0.566754  0.453370  0.566231  1.000000  0.220490  0.056292  0.302700
# 3B  -0.045152  0.435422  0.476582  0.220490  1.000000 -0.430915 -0.454949
# HR   0.676421 -0.066983 -0.091319  0.056292 -0.430915  1.000000  0.425691
# BB   0.395835 -0.136414 -0.117854  0.302700 -0.454949  0.425691  1.000000
# SO  -0.030676 -0.106022 -0.400196 -0.150752 -0.141196  0.359923  0.233652
# SB   0.081068  0.372618  0.415694  0.195027  0.457437 -0.136567 -0.098347
# RA  -0.051780  0.316010  0.223397 -0.218160  0.314125 -0.103903 -0.416445
# ER  -0.049372  0.309686  0.251906 -0.235531  0.340225 -0.085922 -0.452663
# ERA -0.058923  0.255551  0.230628 -0.254854  0.330951 -0.090917 -0.459832
# CG   0.257477 -0.059218  0.113814  0.282895 -0.058674  0.200279  0.484686
# SHO -0.122232 -0.189223 -0.125939  0.073459 -0.064669 -0.068809  0.362907
# SV  -0.075357 -0.133599 -0.152503  0.144282 -0.184189 -0.005146  0.110550
# E   -0.015624  0.322303 -0.032360  0.109864  0.115377 -0.198340 -0.075701
# W    0.442808 -0.087947  0.035307  0.427797 -0.251118  0.307407  0.484342
#
#            SO        SB        RA        ER       ERA        CG       SHO  \
# R   -0.030676  0.081068 -0.051780 -0.049372 -0.058923  0.257477 -0.122232
# AB  -0.106022  0.372618  0.316010  0.309686  0.255551 -0.059218 -0.189223
# H   -0.400196  0.415694  0.223397  0.251906  0.230628  0.113814 -0.125939
# 2B  -0.150752  0.195027 -0.218160 -0.235531 -0.254854  0.282895  0.073459
# 3B  -0.141196  0.457437  0.314125  0.340225  0.330951 -0.058674 -0.064669
# HR   0.359923 -0.136567 -0.103903 -0.085922 -0.090917  0.200279 -0.068809
# BB   0.233652 -0.098347 -0.416445 -0.452663 -0.459832  0.484686  0.362907
# SO   1.000000  0.030968 -0.129745 -0.161612 -0.180368 -0.104017  0.173573
# SB   0.030968  1.000000  0.132290  0.143068  0.126063 -0.033010 -0.092023
# RA  -0.129745  0.132290  1.000000  0.991018  0.986674  0.067182 -0.629403
# ER  -0.161612  0.143068  0.991018  1.000000  0.997248  0.066545 -0.627723
# ERA -0.180368  0.126063  0.986674  0.997248  1.000000  0.074367 -0.628982
# CG  -0.104017 -0.033010  0.067182  0.066545  0.074367  1.000000  0.147245
# SHO  0.173573 -0.092023 -0.629403 -0.627723 -0.628982  0.147245  1.000000
# SV   0.155716 -0.196962 -0.600892 -0.573608 -0.590535 -0.331027  0.193460
# E    0.163744  0.074754  0.211472  0.148533  0.123510 -0.073736 -0.149790
# W    0.111850 -0.157234 -0.812952 -0.809435 -0.819600  0.047176  0.436247
#
#            SV         E         W
# R   -0.075357 -0.015624  0.442808
# AB  -0.133599  0.322303 -0.087947
# H   -0.152503 -0.032360  0.035307
# 2B   0.144282  0.109864  0.427797
# 3B  -0.184189  0.115377 -0.251118
# HR  -0.005146 -0.198340  0.307407
# BB   0.110550 -0.075701  0.484342
# SO   0.155716  0.163744  0.111850
# SB  -0.196962  0.074754 -0.157234
# RA  -0.600892  0.211472 -0.812952
# ER  -0.573608  0.148533 -0.809435
# ERA -0.590535  0.123510 -0.819600
# CG  -0.331027 -0.073736  0.047176
# SHO  0.193460 -0.149790  0.436247
# SV   1.000000 -0.044348  0.668097
# E   -0.044348  1.000000 -0.090225
# W    0.668097 -0.090225  1.000000

# %% [markdown]
# PAIRPLOT

# %%
sns.pairplot(df_final)

# %% [markdown]
# # TRAIN AND TEST DATA

# %%
df_x=df_final.iloc[:,:-1]
print(df_x)
y=df_final.iloc[:,-1]
print(y)
print()
print(df_x.shape)
print(y.shape)
# Out:
#            R    AB         H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  \
# 0   6.586172  5575  7.311886  300  42  139  383   973  104  641  601  3.73
# 1   6.546785  5467  7.207860  277  44  156  439  1264   70  700  653  4.07
# 2   6.507278  5439  7.241366  303  29  141  533  1157   86  640  584  3.67
# 3   6.434547  5533  7.231287  260  27  136  404  1231   68  701  643  3.98
# 4   6.536692  5605  7.323831  289  49  151  455  1259   83  803  746  4.64
# 5   6.793466  5509  7.300473  308  17  232  570  1151   88  670  609  3.80
# 6   6.639876  5567  7.242798  272  19  212  554  1227   63  698  652  4.03
# 7   6.570883  5485  7.223296  246  20  217  418  1331   44  693  646  4.05
# 8   6.469250  5485  7.232733  278  32  167  436  1310   87  642  604  3.74
# 9   6.618739  5640  7.310550  294  33  161  478  1148   71  753  694  4.31
# 10  6.622736  5511  7.258412  279  32  172  503  1233  101  733  680  4.24
# 11  6.593045  5459  7.218177  278  26  230  486  1392  121  618  572  3.57
# 12  6.495266  5417  7.194437  243  21  176  435  1150   52  675  630  3.94
# 13  6.487684  5544  7.229839  262  22  198  478  1336   69  726  677  4.16
# 14  6.543912  5600  7.248504  277  46  146  475  1119   78  729  664  4.14
# 15  6.473891  5484  7.234898  288  39  137  506  1267   69  525  478  2.94
# 16  6.548219  5631  7.288244  292  27  140  461  1322   98  596  532  3.21
# 17  6.536692  5491  7.201916  272  30  171  567  1518   95  608  546  3.36
# 18  6.486161  5480  7.229114  274  34  145  412  1299   84  737  682  4.28
# 19  6.463029  5571  7.232010  257  27  167  496  1255  134  754  700  4.33
# 20  6.527958  5527  7.209340  295  17  177  488  1290   51  613  557  3.43
# 21  6.556778  5428  7.218177  265  13  177  539  1344   57  635  577  3.62
# 22  6.419995  5463  7.259116  236  40  120  375  1150  112  678  638  4.02
# 23  6.352629  5420  7.216709  251  18  100  471  1107   69  760  698  4.41
# 24  6.440947  5529  7.226209  272  37  130  387  1274   88  809  749  4.69
# 25  6.504288  5385  7.205635  263  26  187  563  1258   59  595  553  3.44
# 26  6.546785  5565  7.304516  288  39  136  457  1159   93  627  597  3.72
# 27  6.580639  5649  7.309881  289  48  154  490  1312  132  713  659  4.04
# 28  6.478510  5457  7.189168  260  36  148  426  1327   82  731  655  4.09
# 29  6.603944  5572  7.299797  274  49  186  388  1283   97  844  799  5.04
#
#           CG       SHO        SV         E
# 0   1.098612  2.197225  4.043051  4.488636
# 1   1.098612  2.564949  3.828641  4.465908
# 2   2.484907  2.397895  3.663562  4.382027
# 3   2.079442  2.302585  3.637586  4.624973
# 4   2.079442  2.564949  3.583519  4.465908
# 5   2.079442  2.397895  3.555348  4.488636
# 6   1.386294  1.609438  3.891820  4.543295
# 7   0.000000  2.397895  3.784190  4.356709
# 8   0.693147  2.564949  4.110874  4.564348
# 9   1.386294  2.397895  3.713572  4.584967
# 10  1.791759  2.302585  3.828641  4.787492
# 11  1.791759  2.639057  3.688879  4.454347
# 12  1.098612  2.564949  3.850148  4.543295
# 13  1.945910  2.564949  3.828641  4.553877
# 14  1.791759  2.772589  3.367296  4.844187
# 15  0.693147  2.772589  4.143135  4.574711
# 16  0.000000  2.639057  4.007333  4.812184
# 17  1.945910  3.091042  3.891820  4.718499
# 18  0.693147  2.079442  3.713572  4.762174
# 19  1.098612  2.197225  3.583519  4.510860
# 20  0.693147  2.708050  3.931826  4.488636
# 21  1.609438  2.639057  3.737670  4.510860
# 22  0.000000  2.564949  3.583519  4.356709
# 23  1.386294  2.397895  3.806662  4.510860
# 24  0.693147  2.079442  3.583519  4.770685
# 25  1.945910  3.091042  3.871201  4.330733
# 26  2.079442  2.944439  3.737670  4.369448
# 27  0.693147  2.564949  3.806662  4.465908
# 28  0.693147  1.945910  3.737670  4.532599
# 29  1.609438  1.609438  3.610918  4.564348
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 5      93
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64
#
# (30, 16)
# (30,)

# %%
x=df_x

# %% [markdown]
# # TRAINING AND TESTING - VARIOUS MODELS

# %% [markdown]
# FUNCTION DECLARATION

# %%
def maxr2_score(regr,x,y):
    max_r_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print("R2 Score corresponding to ",r_state," is ",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("Maximum R2 Score corresponds to ",final_r_state," is ",max_r_score)
    return(final_r_state)

# %% [markdown]
# LINEAR REGRESSION

# %%
lr=LinearRegression()
r_state=maxr2_score(lr,x,y)
# Out:
# R2 Score corresponding to  42  is  0.8040230760493979
# R2 Score corresponding to  43  is  -0.5270300230494254
# R2 Score corresponding to  44  is  0.7532264252118233
# R2 Score corresponding to  45  is  0.8078201120487303
# R2 Score corresponding to  46  is  0.312140480610715
# R2 Score corresponding to  47  is  0.6500055183796625
# R2 Score corresponding to  48  is  0.8921815863716965
# R2 Score corresponding to  49  is  -0.2416282470434845
# R2 Score corresponding to  50  is  0.6125549749306785
# R2 Score corresponding to  51  is  0.44100750240058284
# R2 Score corresponding to  52  is  0.5496042930627125
# R2 Score corresponding to  53  is  0.42958892361107415
# R2 Score corresponding to  54  is  0.6728792808445463
# R2 Score corresponding to  55  is  0.83542052045186
# R2 Score corresponding to  56  is  0.22451789309249082
# R2 Score corresponding to  57  is  -0.5755020933498873
# R2 Score corresponding to  58  is  0.24993207729329647
# R2 Score corresponding to  59  is  -0.2856171229736322
# R2 Score corresponding to  60  is  -0.6780104490851482
# R2 Score corresponding to  61  is  0.006876381218606009
# R2 Score corresponding to  62  is  0.5486093912569336
# R2 Score corresponding to  63  is  0.7504407148591926
# R2 Score corresponding to  64  is  0.8471327705424734
# R2 Score corresponding to  65  is  0.7159520414075764
# R2 Score corresponding to  66  is  0.1357195241967275
# R2 Score corresponding to  67  is  0.7775655422440353
# R2 Score corresponding to  68  is  0.6019420243357787
# R2 Score corresponding to  69  is  0.7631974497677458
# R2 Score corresponding to  70  is  -1.5036545947512483
# R2 Score corresponding to  71  is  -0.06241731770262726
# R2 Score corresponding to  72  is  0.7634652284856405
# R2 Score corresponding to  73  is  0.6893908725403433
# R2 Score corresponding to  74  is  -1.5217523456053117
# R2 Score corresponding to  75  is  0.7342986407260791
# R2 Score corresponding to  76  is  -0.32728287890404495
# R2 Score corresponding to  77  is  -0.2927609165146765
# R2 Score corresponding to  78  is  0.5648504163326764
# R2 Score corresponding to  79  is  0.25238715500839115
# R2 Score corresponding to  80  is  -0.02088554287263822
# R2 Score corresponding to  81  is  -4.691686690983612
# R2 Score corresponding to  82  is  0.7643130984811867
# R2 Score corresponding to  83  is  0.8361380514742273
# R2 Score corresponding to  84  is  0.7206100063043601
# R2 Score corresponding to  85  is  0.7532808884679381
# R2 Score corresponding to  86  is  0.7153763882483988
# R2 Score corresponding to  87  is  0.0019808576187259064
# R2 Score corresponding to  88  is  -2.5649236404136606
# R2 Score corresponding to  89  is  -0.5950036713131037
# R2 Score corresponding to  90  is  0.8526364944644034
# R2 Score corresponding to  91  is  0.8322126203560107
# R2 Score corresponding to  92  is  0.6889051917860599
# R2 Score corresponding to  93  is  0.37393651140083706
# R2 Score corresponding to  94  is  -0.5971067497489104
# R2 Score corresponding to  95  is  0.4494675080209902
# R2 Score corresponding to  96  is  0.2624293126032179
# R2 Score corresponding to  97  is  0.7874189943468131
# R2 Score corresponding to  98  is  0.626419463243491
# R2 Score corresponding to  99  is  0.839962235192547
# R2 Score corresponding to  100  is  0.056294883301475585
# Maximum R2 Score corresponds to  48  is  0.8921815863716965

# %%
print("Mean R2 Score for Linear Regression is ",cross_val_score(linear_model.LinearRegression(),x,y,cv=5,scoring='r2').mean())
print("Standard Deviation in R2 Score for Linear Regression is ",cross_val_score(linear_model.LinearRegression(),x,y,cv=5,scoring='r2').std())
# Out:
# Mean R2 Score for Linear Regression is  -0.33434511806842393
# Standard Deviation in R2 Score for Linear Regression is  1.7721685821573807

# %% [markdown]
# KNEIGHBORS REGRESSOR

# %%
neighbors={"n_neighbors":range(1,10)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors,cv=5)
gknr.fit(x,y)
gknr.best_params_
# Out:
# {'n_neighbors': 9}

# %%
knr=KNeighborsRegressor(n_neighbors=9)
r_state=maxr2_score(knr,x,y)
# Out:
# R2 Score corresponding to  42  is  0.5208250259970755
# R2 Score corresponding to  43  is  0.25528417994878216
# R2 Score corresponding to  44  is  0.44599635896976786
# R2 Score corresponding to  45  is  0.20322886989553712
# R2 Score corresponding to  46  is  0.28245714875241323
# R2 Score corresponding to  47  is  0.3841993287786166
# R2 Score corresponding to  48  is  0.5170962052682484
# R2 Score corresponding to  49  is  0.3965557257577864
# R2 Score corresponding to  50  is  0.36735240099306876
# R2 Score corresponding to  51  is  0.2360557960557963
# R2 Score corresponding to  52  is  0.2803532008830022
# R2 Score corresponding to  53  is  -0.04395580636094332
# R2 Score corresponding to  54  is  0.2993605115907273
# R2 Score corresponding to  55  is  0.3453208538842931
# R2 Score corresponding to  56  is  0.5448700534275105
# R2 Score corresponding to  57  is  0.29170045958367163
# R2 Score corresponding to  58  is  -0.49860744649662836
# R2 Score corresponding to  59  is  0.2737581758904889
# R2 Score corresponding to  60  is  0.3957883164638538
# R2 Score corresponding to  61  is  0.3093752382196958
# R2 Score corresponding to  62  is  0.5609895609895612
# R2 Score corresponding to  63  is  0.5692156600151782
# R2 Score corresponding to  64  is  0.5031991328287628
# R2 Score corresponding to  65  is  0.3382931267241889
# R2 Score corresponding to  66  is  0.4143475572047002
# R2 Score corresponding to  67  is  0.09083820662768016
# R2 Score corresponding to  68  is  0.1881313131313127
# R2 Score corresponding to  69  is  0.3772316930641202
# R2 Score corresponding to  70  is  0.061423294433004316
# R2 Score corresponding to  71  is  0.5806878306878306
# R2 Score corresponding to  72  is  0.5220243673851923
# R2 Score corresponding to  73  is  0.33173894298427564
# R2 Score corresponding to  74  is  0.07326992004411303
# R2 Score corresponding to  75  is  0.3919372900335947
# R2 Score corresponding to  76  is  0.41766113256394055
# R2 Score corresponding to  77  is  0.5114087301587305
# R2 Score corresponding to  78  is  0.5384761039157766
# R2 Score corresponding to  79  is  0.3760134916001815
# R2 Score corresponding to  80  is  0.2925992340218282
# R2 Score corresponding to  81  is  -2.3517762660619836
# R2 Score corresponding to  82  is  0.4845749639799982
# R2 Score corresponding to  83  is  0.6052293396599449
# R2 Score corresponding to  84  is  0.09118112014453472
# R2 Score corresponding to  85  is  0.5828341473904091
# R2 Score corresponding to  86  is  0.6609714873603761
# R2 Score corresponding to  87  is  0.5435358088287905
# R2 Score corresponding to  88  is  -1.3987953716912362
# R2 Score corresponding to  89  is  0.6599468666979214
# R2 Score corresponding to  90  is  0.4178455848358761
# R2 Score corresponding to  91  is  -0.010644346595793053
# R2 Score corresponding to  92  is  0.3447496223296931
# R2 Score corresponding to  93  is  0.7445638071513829
# R2 Score corresponding to  94  is  0.7538480038480038
# R2 Score corresponding to  95  is  -0.9219709659408151
# R2 Score corresponding to  96  is  3.3306690738754696e-16
# R2 Score corresponding to  97  is  0.4000382811752321
# R2 Score corresponding to  98  is  0.08610965753822886
# R2 Score corresponding to  99  is  0.4774261651440246
# R2 Score corresponding to  100  is  0.06555753614577164
# Maximum R2 Score corresponds to  94  is  0.7538480038480038

# %%
print("Mean R2 Score for KNN Regression is ",cross_val_score(knr,x,y,cv=5,scoring="r2").mean())
print("Standard Deviation in R2 Score for KNN Regression is ",cross_val_score(knr,x,y,cv=5,scoring='r2').std())
# Out:
# Mean R2 Score for KNN Regression is  -0.3200730040419191
# Standard Deviation in R2 Score for KNN Regression is  0.8224815266301239

# %% [markdown]
# LASSO REGRESSION

# %%
ls=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1]}
clf=GridSearchCV(ls,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'alpha': 0.01}

# %%
ls=Lasso(alpha=0.01)
r_state=maxr2_score(ls,x,y)
# Out:
# R2 Score corresponding to  42  is  0.7897776672166174
# R2 Score corresponding to  43  is  0.05987206177887994
# R2 Score corresponding to  44  is  0.8165611784199148
# R2 Score corresponding to  45  is  0.8644830452889181
# R2 Score corresponding to  46  is  0.5342531289031117
# R2 Score corresponding to  47  is  0.7508376757052297
# R2 Score corresponding to  48  is  0.9420689685974108
# R2 Score corresponding to  49  is  0.49845986224647165
# R2 Score corresponding to  50  is  0.7274452302405787
# R2 Score corresponding to  51  is  0.5878491731364666
# R2 Score corresponding to  52  is  0.6278042026258837
# R2 Score corresponding to  53  is  0.42020398694234284
# R2 Score corresponding to  54  is  0.6708297697347687
# R2 Score corresponding to  55  is  0.780606684696065
# R2 Score corresponding to  56  is  0.8937464676076221
# R2 Score corresponding to  57  is  -1.047747784525931
# R2 Score corresponding to  58  is  0.42908653529006724
# R2 Score corresponding to  59  is  -0.32750270831355177
# R2 Score corresponding to  60  is  0.031910340739180865
# R2 Score corresponding to  61  is  -0.163857983746303
# R2 Score corresponding to  62  is  0.543437533683802
# R2 Score corresponding to  63  is  0.8383754390834655
# R2 Score corresponding to  64  is  0.8430862232460163
# R2 Score corresponding to  65  is  0.7541526454791573
# R2 Score corresponding to  66  is  0.058186230325068644
# R2 Score corresponding to  67  is  0.7729501769100844
# R2 Score corresponding to  68  is  0.9399839771149505
# R2 Score corresponding to  69  is  0.6433669883155088
# R2 Score corresponding to  70  is  0.22231094484469116
# R2 Score corresponding to  71  is  0.4498438607225518
# R2 Score corresponding to  72  is  0.7743473030660151
# R2 Score corresponding to  73  is  0.8000126812007993
# R2 Score corresponding to  74  is  -0.9060423080941207
# R2 Score corresponding to  75  is  0.8869656989099068
# R2 Score corresponding to  76  is  0.07306041605888569
# R2 Score corresponding to  77  is  -0.3193230634092439
# R2 Score corresponding to  78  is  0.7045348026864114
# R2 Score corresponding to  79  is  0.22691749406555306
# R2 Score corresponding to  80  is  -0.39848410341509477
# R2 Score corresponding to  81  is  -4.895662494418476
# R2 Score corresponding to  82  is  0.7912764594915909
# R2 Score corresponding to  83  is  0.834255449456434
# R2 Score corresponding to  84  is  0.7452859500782862
# R2 Score corresponding to  85  is  0.705813506318919
# R2 Score corresponding to  86  is  0.7415420020835625
# R2 Score corresponding to  87  is  0.4365052058555119
# R2 Score corresponding to  88  is  -3.400142423166524
# R2 Score corresponding to  89  is  -0.36485292151306314
# R2 Score corresponding to  90  is  0.8535336501957278
# R2 Score corresponding to  91  is  0.8995456166811524
# R2 Score corresponding to  92  is  0.8064843293626824
# R2 Score corresponding to  93  is  0.7697714457683426
# R2 Score corresponding to  94  is  0.18633582465508436
# R2 Score corresponding to  95  is  0.3571930375944431
# R2 Score corresponding to  96  is  0.5257103684965543
# R2 Score corresponding to  97  is  0.7836103907880083
# R2 Score corresponding to  98  is  0.42312703185744416
# R2 Score corresponding to  99  is  0.8563939654509104
# R2 Score corresponding to  100  is  0.7784215819618635
# Maximum R2 Score corresponds to  48  is  0.9420689685974108

# %%
print("Mean R2 Score for Lasso Regression is ",cross_val_score(ls,x,y,cv=5,scoring="r2").mean())
print("Standard Deviation in R2 Score for Lasso Regression is ",cross_val_score(ls,x,y,cv=5,scoring="r2").std())
# Out:
# Mean R2 Score for Lasso Regression is  -0.22834533176286195
# Standard Deviation in R2 Score for Lasso Regression is  1.8287299190595632

# %% [markdown]
# RIDGE REGRESSION

# %%
rd=Ridge()
parameters={"alpha":[0.001,0.01,0.1,1]}
clf=GridSearchCV(rd,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'alpha': 0.001}

# %%
rd=Ridge(alpha=0.001)
r_state=maxr2_score(rd,x,y)
# Out:
# R2 Score corresponding to  42  is  0.8026385347072127
# R2 Score corresponding to  43  is  -0.2718533332834472
# R2 Score corresponding to  44  is  0.75742926566098
# R2 Score corresponding to  45  is  0.8525837858437362
# R2 Score corresponding to  46  is  0.36851855927114063
# R2 Score corresponding to  47  is  0.6685609480100738
# R2 Score corresponding to  48  is  0.93009524607087
# R2 Score corresponding to  49  is  0.11631382078628438
# R2 Score corresponding to  50  is  0.654073248241731
# R2 Score corresponding to  51  is  0.4999788467133711
# R2 Score corresponding to  52  is  0.6052818688515853
# R2 Score corresponding to  53  is  0.4626455229950438
# R2 Score corresponding to  54  is  0.6613885222013106
# R2 Score corresponding to  55  is  0.8323883310946563
# R2 Score corresponding to  56  is  0.6946865692710258
# R2 Score corresponding to  57  is  -0.6907238546838488
# R2 Score corresponding to  58  is  0.3259877236562152
# R2 Score corresponding to  59  is  -0.3092112379761218
# R2 Score corresponding to  60  is  -0.2920253680563698
# R2 Score corresponding to  61  is  -0.030770675750982246
# R2 Score corresponding to  62  is  0.5687643193886351
# R2 Score corresponding to  63  is  0.7972405725968889
# R2 Score corresponding to  64  is  0.862936175374665
# R2 Score corresponding to  65  is  0.7858963780277736
# R2 Score corresponding to  66  is  0.13391599384864927
# R2 Score corresponding to  67  is  0.7800988085891027
# R2 Score corresponding to  68  is  0.6417794477059546
# R2 Score corresponding to  69  is  0.7181707448072898
# R2 Score corresponding to  70  is  -0.7559953905748737
# R2 Score corresponding to  71  is  0.20545871027585905
# R2 Score corresponding to  72  is  0.7868456019500659
# R2 Score corresponding to  73  is  0.7109205197609723
# R2 Score corresponding to  74  is  -1.1872816519054967
# R2 Score corresponding to  75  is  0.8291870285990116
# R2 Score corresponding to  76  is  -0.06574164139183414
# R2 Score corresponding to  77  is  -0.29285381603699756
# R2 Score corresponding to  78  is  0.6254375840626211
# R2 Score corresponding to  79  is  0.23982558798491405
# R2 Score corresponding to  80  is  -0.16008733006788334
# R2 Score corresponding to  81  is  -4.405337900555954
# R2 Score corresponding to  82  is  0.7704394686050389
# R2 Score corresponding to  83  is  0.8424622836751647
# R2 Score corresponding to  84  is  0.7088213563218001
# R2 Score corresponding to  85  is  0.7538126108851494
# R2 Score corresponding to  86  is  0.7195283019399439
# R2 Score corresponding to  87  is  0.3082851190175546
# R2 Score corresponding to  88  is  -2.8469131452915897
# R2 Score corresponding to  89  is  -0.5320832640413573
# R2 Score corresponding to  90  is  0.8523463053394482
# R2 Score corresponding to  91  is  0.8597102940020497
# R2 Score corresponding to  92  is  0.7466928486289992
# R2 Score corresponding to  93  is  0.5451232970471912
# R2 Score corresponding to  94  is  -0.04313324367493698
# R2 Score corresponding to  95  is  0.44832816494302996
# R2 Score corresponding to  96  is  0.393284058862321
# R2 Score corresponding to  97  is  0.7896808126832189
# R2 Score corresponding to  98  is  0.5798790115137811
# R2 Score corresponding to  99  is  0.8461127672416104
# R2 Score corresponding to  100  is  0.37861923235917827
# Maximum R2 Score corresponds to  48  is  0.93009524607087

# %%
print("Mean R2 Score for Ridge Regression is ",cross_val_score(rd,x,y,cv=5,scoring="r2").mean())
print("Standard Deviation in R2 Score for Ridge Regression is ",cross_val_score(rd,x,y,cv=5,scoring="r2").std())
# Out:
# Mean R2 Score for Ridge Regression is  -0.35465515069752057
# Standard Deviation in R2 Score for Ridge Regression is  1.846066668801058

# %% [markdown]
# ELASTIC NET REGRESSION

# %%
enr=ElasticNet()
parameters={"alpha":[0.001,0.01,0.1,1]}
clf=GridSearchCV(enr,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'alpha': 0.1}

# %%
enr=ElasticNet(alpha=0.1)
r_state=maxr2_score(enr,x,y)
# Out:
# R2 Score corresponding to  42  is  0.6984092120996543
# R2 Score corresponding to  43  is  0.04055025087177477
# R2 Score corresponding to  44  is  0.5494053651005151
# R2 Score corresponding to  45  is  0.5730204222312734
# R2 Score corresponding to  46  is  0.4182816867648804
# R2 Score corresponding to  47  is  0.7338120848157772
# R2 Score corresponding to  48  is  0.9254832171050138
# R2 Score corresponding to  49  is  0.306326904409855
# R2 Score corresponding to  50  is  0.45874292472055056
# R2 Score corresponding to  51  is  0.4751698266811214
# R2 Score corresponding to  52  is  -0.7750230043836279
# R2 Score corresponding to  53  is  0.49347713982478736
# R2 Score corresponding to  54  is  0.6232045590049
# R2 Score corresponding to  55  is  0.0696100134719293
# R2 Score corresponding to  56  is  0.03982543012972517
# R2 Score corresponding to  57  is  -1.4352442732456026
# R2 Score corresponding to  58  is  -0.19939697867690875
# R2 Score corresponding to  59  is  -0.8784028578907725
# R2 Score corresponding to  60  is  -0.13775235666212104
# R2 Score corresponding to  61  is  0.13078580926945582
# R2 Score corresponding to  62  is  0.5929755220105659
# R2 Score corresponding to  63  is  0.6309046620560685
# R2 Score corresponding to  64  is  0.7399062491687881
# R2 Score corresponding to  65  is  0.3840418876808879
# R2 Score corresponding to  66  is  0.4100040600961503
# R2 Score corresponding to  67  is  0.46052826030876315
# R2 Score corresponding to  68  is  0.522243375146044
# R2 Score corresponding to  69  is  0.5007491145882288
# R2 Score corresponding to  70  is  -0.2366006750176346
# R2 Score corresponding to  71  is  0.43586584732579237
# R2 Score corresponding to  72  is  0.4487789353916404
# R2 Score corresponding to  73  is  0.5731391453896031
# R2 Score corresponding to  74  is  0.3838870070509556
# R2 Score corresponding to  75  is  0.9212272794665166
# R2 Score corresponding to  76  is  0.07113724488618545
# R2 Score corresponding to  77  is  -1.4076095586688142
# R2 Score corresponding to  78  is  0.27998036120315284
# R2 Score corresponding to  79  is  0.28249150411193
# R2 Score corresponding to  80  is  -0.7727579189859273
# R2 Score corresponding to  81  is  -4.766998324999339
# R2 Score corresponding to  82  is  0.6265745308714573
# R2 Score corresponding to  83  is  0.821037477606547
# R2 Score corresponding to  84  is  0.536860317476888
# R2 Score corresponding to  85  is  0.4544165657639364
# R2 Score corresponding to  86  is  0.18602554940849647
# R2 Score corresponding to  87  is  0.2986993022015346
# R2 Score corresponding to  88  is  -5.513573498251564
# R2 Score corresponding to  89  is  0.10964709170412423
# R2 Score corresponding to  90  is  0.4841064639694156
# R2 Score corresponding to  91  is  0.2988353834133136
# R2 Score corresponding to  92  is  0.7602737387225211
# R2 Score corresponding to  93  is  0.4659592949787571
# R2 Score corresponding to  94  is  0.14003302089155478
# R2 Score corresponding to  95  is  -1.202821432910644
# R2 Score corresponding to  96  is  -0.3525181678659619
# R2 Score corresponding to  97  is  0.5107325693611979
# R2 Score corresponding to  98  is  -0.0005242238576124159
# R2 Score corresponding to  99  is  0.7887649580014889
# R2 Score corresponding to  100  is  -0.006463523266758031
# Maximum R2 Score corresponds to  48  is  0.9254832171050138

# %%
print("Mean R2 Score for Elastic Net Regression is ",cross_val_score(enr,x,y,cv=5,scoring="r2").mean())
print("Standard Deviation in R2 Score for Elastic Net Regression is ",cross_val_score(enr,x,y,cv=5,scoring="r2").std())
# Out:
# Mean R2 Score for Elastic Net Regression is  -0.3129955786614901
# Standard Deviation in R2 Score for Elastic Net Regression is  1.6156442723103444

# %% [markdown]
# # BEST MODEL

# %% [markdown]
# R2 SCORE AND RMSE

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=48,test_size=0.20)
ls=Lasso()
ls.fit(x_train,y_train)
y_pred=ls.predict(x_test)
print("R2 Score is ",r2_score(y_test,y_pred))
print("RMSE is ",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2 Score is  0.9064072797305218
# RMSE is  3.679639502132129

# %% [markdown]
# CROSS VALIDATION

# %%
score=cross_val_score(ls,x,y,cv=5)
print('Score is ',score)
print('Mean Score is ', score.mean())
print('Standard Deviation is ',score.std())
# Out:
# Score is  [ 0.23579739 -3.49980022  0.09423649  0.58618923  0.90036417]
# Mean Score is  -0.3366425866912267
# Standard Deviation is  1.6062823397307249

# %% [markdown]
# # PICKLE

# %%
joblib.dump(ls,'baseball.pkl')
# Out:
# ['baseball.pkl']
